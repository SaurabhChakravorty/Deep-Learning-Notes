# %% [markdown]
# # Introduction to Keras
#
# After the first wave of autodifferentiation frameworks the need for a more user friendly, high level "scikit like" computational library focused on neural networks was obvious. Though different approaches were taken to this ([TFlearn](http://tflearn.org/), [SKFlow](https://github.com/tensorflow/skflow)), the most famous and widespread one is [Keras](https://keras.io/) by [François Chollet](https://www.linkedin.com/in/fchollet/). (The project in fact became so popular, that TensorFlow decided to incorporate it into the main codebase, so [tf.Keras](https://www.tensorflow.org/api_docs/python/tf/keras) is - since 2017 - part of the main TF deployment, and finally, in 2019 it completely puhed out tf.layers from support, and became the de facto standard layer API in TF.)
#
# The library aims to be an abstract, high level "frontend" for other libraries. Currently the models defined in Keras can be executed in TensorFlow, [CNTK](https://github.com/Microsoft/CNTK) and [Theano](http://deeplearning.net/software/theano/). (As a "joke", for tf.keras being part of TF, Keras' backend is TF itself. :-)
#
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTIeDOxUfzg_LhPmGrpXp2r5QDwAFBQ7CpqdxnHzsThBOFKv4p-" width=55%>
#
# It also lays emphasis on the high level, compact syntax with minimal "boilerplate", thus aims rapid prototyping.
#
# It has two "API" approaches, the more object oriented _"Sequential"_ API, and the _"Functional"_ API.
#
# We well skim through an example in both approaches.

# %% [markdown]
# ## Keras Functional API
#
# In this approach the Keras model is built up of a series of function calls, each taking the (some) other function's output as input.
#
# The underlying computational graph is being built up when we instantiate a `model=Model()` object, defining it's inputs and outputs (whereby inputs are self explanatory, and _outputs are the last function_ we have called in the "chain"). The compile to a eg. a TF graph happens when we call `model.compile()`.
#
# The main advantage of the Functional API is, that it does not presuppose the "sequential" nature of the "layers", operations, thus parallelly outputting two vectors, concatenating them and moving on with the model is not a problem,... It's increased flexibility can be advantageous.
#
# In fact, Keras' functional API heavily influenced `tf.layers`, or better to say it is completely overtaking it, so basically all the layers we have used thus far are in fact Keras layers.
#
# The code comment says:
# ```
# class Layer(base_layer.Layer):
#   """Base layer class.
#   It is considered legacy, and we recommend the use of `tf.keras.layers.Layer`
#   instead.
# ```
# [source](https://github.com/tensorflow/tensorflow/blob/693b339/tensorflow/python/layers/base.py#L37)

# %% [markdown]
# ## Keras Sequential API
#
# As mentioned above, "Sequential" is an object oriented, strictly sequential model for building up networks.
#
# The basic idea is the same, but - beside the sequence - the handling of `input_shape` (or sometimes only `input_dim` for a vector, which is vector length) here makes things a bit more circumspect.
#
# <img src="https://www.learnopencv.com/wp-content/uploads/2017/09/keras-workflow.jpg" width=65%>
#
# ```
# from keras.layers import Dense
# from keras.models import Sequential
#
# model = Sequential()
#
# model.add(Dense(units=number_of_hidden_units, input_shape=(data_rows_number,data_columns_number)))
# # Please note, that we have to deal with input_dim or input_shape here!
#
# model.add(Dense(units=number_of_second_layer_hidden_units, activation='relu'))
# model.add(Dense(units=number_of_classes, activation='softmax'))
#
# model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])
#
# # In case of regression this would be:
# # model.add(units=1, activation='linear')
# # model.compile(loss='mean_squared_error', optimizer='Adam', metrics=['MeanAbsoluteError'])
#
# model.fit(x_train, y_train, epochs=5, batch_size=32)
#
# ```
#
# <img src="http://drive.google.com/uc?export=view&id=1RB7e5QJEbPIwMFJBJymVb7g-om4t-eST" width=75%>

# %% [markdown]
# ## Same network defined in Functional API
#
# ```
# from keras.layers import Dense
# from keras import Input
#
# input_layer = Input(shape=(data_rows_number,data_columns_number))
#
# layer1_out = Dense(number_of_hidden_units, activation='linear')(input_layer)
# layer2_out = Dense(number_of_second_layer_hidden_units, activation='relu')(layer1_out)
# output = Dense(number_of_classes, activation='softmax')(layer2_out)
#
# # In case of regression this would be:
# # output = Dense(1, activation='linear')(layer2_out)
#
#
# model = Model(inputs=input_layer, outputs=output)
# model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'])
#
# # In case of regression this would be:
# # model.compile(loss='mean_squared_error', optimizer='Adam', metrics=['MeanAbsoluteError'])
#
# model.fit(x_train, y_train, epochs=5, batch_size=32)
#
# ```

# %% [markdown]
# ## Example for sequential with spiral dataset
#
# In the following we are going to build and fit a Neural Network for the spiral like dataset. It will be a classfication problem solved by keras. We have modified the original exmple (<a href="http://datahacker.rs/tf-an-implementation-of-a-shallow-neural-network-in-keras-spirals-dataset/">source</a>) a little bit in order to converge later, and have real-life-like loss curves.

# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
import warnings
from mpl_toolkits import mplot3d
from matplotlib import cm
from keras.models import Sequential
from keras.layers import Dense
from keras import backend as K
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import adam
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_s_curve
warnings.filterwarnings("ignore")
plt.style.use('ggplot')
# Out:
# Using TensorFlow backend.

# %%
# Fix random seed for reproducibility
seed = 7
np.random.seed(seed)

# We need to generate two sets of data
def spirals(points, noise=1.5):
    n = np.sqrt(np.random.rand(points,1)) * 780 * (2*np.pi)/360
    d1x = -np.cos(n)*n + np.random.rand(points,1) * noise
    d1y = np.sin(n)*n + np.random.rand(points,1) * noise
    return (np.vstack((np.hstack((d1x,d1y)),np.hstack((-d1x,-d1y)))), 
            np.hstack((np.zeros(points),np.ones(points))))
X, y = spirals(1000)

# %%
plt.figure(figsize=(12,8))
plt.scatter(X[:,0], X[:,1], c=y ,cmap=cm.coolwarm)
plt.title('Dataset')
plt.axis('equal');

# %%
print('X:\t{}' .format(X.shape))
print('y:\t{}' .format(y.shape))
print(type(X))
print(type(y))

# Spliting data into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

X_valid, X_test, y_valid, y_test = train_test_split(X_test, y_test, test_size=0.50, random_state=42)

# Checking the shape of the input data
print('X_train:\t{}' .format(X_train.shape))
print('y_train:\t{}' .format(y_train.shape))
print('X_valid:\t\t{}'.format(X_valid.shape))
print('y_valid:\t\t{}'.format(y_valid.shape))
print('X_test:\t\t{}'.format(X_test.shape))
print('y_test:\t\t{}'.format(y_test.shape))
# Out:
# X:	(2000, 2)
# y:	(2000,)
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# X_train:	(1400, 2)
# y_train:	(1400,)
# X_valid:		(300, 2)
# y_valid:		(300,)
# X_test:		(300, 2)
# y_test:		(300,)

# %%
# Hyperparameters
training_epochs = 1000 # Total number of training epochs
learning_rate = 0.005 # The learning rate

# create a model
def create_model():
      model = Sequential()
      # Input layer
      model.add(Dense(14, input_dim=2, kernel_initializer='normal', activation='relu'))
      model.add(Dense(8,activation='relu'))
      # Output layer
      model.add(Dense(1, activation='sigmoid'))

      # Compile a model
      model.compile(loss='binary_crossentropy', optimizer=adam(learning_rate), metrics=['accuracy'])
      return model
model = create_model()
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_139 (Dense)            (None, 14)                42
# _________________________________________________________________
# dense_140 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_141 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 171
# Trainable params: 171
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Let's trains the model for a given number of epochs.
results = model.fit(
 X_train, y_train,
 epochs= training_epochs,
 batch_size = 512,
 validation_data = (X_valid, y_valid)
# ,verbose = 0
)
# Out:
# Train on 1400 samples, validate on 300 samples
# Epoch 1/1000
# 1400/1400 [==============================] - 2s 2ms/step - loss: 0.7091 - acc: 0.4786 - val_loss: 0.6888 - val_acc: 0.5533
# Epoch 2/1000
# 1400/1400 [==============================] - 0s 8us/step - loss: 0.6927 - acc: 0.5193 - val_loss: 0.6829 - val_acc: 0.5300
# Epoch 3/1000
# 1400/1400 [==============================] - 0s 9us/step - loss: 0.6885 - acc: 0.5243 - val_loss: 0.6806 - val_acc: 0.5367
# Epoch 4/1000
# 1400/1400 [==============================] - 0s 10us/step - loss: 0.6850 - acc: 0.5300 - val_loss: 0.6798 - val_acc: 0.5233
# Epoch 5/1000
# 1400/1400 [==============================] - 0s 9us/step - loss: 0.6811 - acc: 0.5471 - val_loss: 0.6799 - val_acc: 0.5467
# Epoch 6/1000
# 1400/1400 [==============================] - 0s 9us/step - loss: 0.6796 - acc: 0.5579 - val_loss: 0.6815 - val_acc: 0.5367
# Epoch 7/1000
# 1400/1400 [==============================] - 0s 9us/step - loss: 0.6779 - acc: 0.5636 - val_loss: 0.6819 - val_acc: 0.5500
# Epoch 8/1000
# 1400/1400 [==============================] - 0s 10us/step - loss: 0.6762 - acc: 0.5621 - val_loss: 0.6810 - val_acc: 0.5500
# Epoch 9/1000
# 1400/1400 [==============================] - 0s 9us/step - loss: 0.6752 - acc: 0.5664 - val_loss: 0.6801 - val_acc: 0.5400
# Epoch 10/1000
# 1400/1400 [==============================] - 0s 9us/step - loss: 0.6743 - acc: 0.5657 - val_loss: 0.6798 - val_acc: 0.5367
# Epoch 11/1000
# 1400/1400 [==============================] - 0s 9us/step - loss: 0.6736 - acc: 0.5643 - val_loss: 0.6797 - val_acc: 0.5533
# Epoch 12/1000
# 1400/1400 [==============================] - 0s 10us/step - loss: 0.6724 - acc: 0.5671 - val_loss: 0.6798 - val_acc: 0.5500
# Epoch 13/1000
# 1400/1400 [==============================] - 0s 8us/step - loss: 0.6715 - acc: 0.5736 - val_loss: 0.6803 - val_acc: 0.5600
# Epoch 14/1000
history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')

max_loss = np.max(results.history['loss'])
min_loss = np.min(results.history['loss'])
print("Maximum Loss : {:.4f}".format(max_loss))
print("")
print("Minimum Loss : {:.4f}".format(min_loss))
print("")
print("Loss difference : {:.4f}".format((max_loss - min_loss)))
# Out:
# Maximum Loss : 0.7091
#
# Minimum Loss : 0.1000
#
# Loss difference : 0.6091

# %%
# The model can generate output predictions for the input samples.
prediction_values = model.predict_classes(X_test)
print("Prediction values shape:", prediction_values.shape)

# Now we can check the accuracy of our model
print("Evaluating on training set...")
(loss, accuracy) = model.evaluate(X_train, y_train)
print("loss={:.4f}, accuracy: {:.4f}%".format(loss,accuracy * 100))

print("Evaluating on testing set...")
(loss, accuracy) = model.evaluate(X_test, y_test)
print("loss={:.4f}, accuracy: {:.4f}%".format(loss,accuracy * 100))
# Out:
# Prediction values shape: (300, 1)
# Evaluating on training set...
# 1400/1400 [==============================] - 0s 32us/step
# loss=0.1050, accuracy: 95.8571%
# Evaluating on testing set...
# 300/300 [==============================] - 0s 38us/step
# loss=0.1089, accuracy: 95.0000%

# %%
# Visualization of the model predictions on our training set
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.scatter(X_test[:,0], X_test[:,1], c=y_test ,cmap=cm.coolwarm)
plt.title('Test set original')
plt.axis('equal');

# Visualization of the model predictions on our test set
plt.subplot(122)
plt.scatter(X_test[:,0], X_test[:,1], c=prediction_values[:,0], cmap=cm.coolwarm)
plt.title('Model predictions on Test set')
plt.axis('equal');

# %%
# We can now see how our model separates the classes.
plt.figure(figsize=(12,8))
xx = np.linspace(-20, 20, 400)
yy = np.linspace(-20, 20, 400)
gx, gy = np.meshgrid(xx, yy)
Z = model.predict(np.c_[gx.ravel(), gy.ravel()])
Z = Z.reshape(gx.shape)
plt.contourf(gx, gy, Z, cmap=plt.cm.coolwarm, alpha=0.7)

axes = plt.gca()
axes.set_xlim([-20, 20])
axes.set_ylim([-20, 20])
plt.grid('off')
plt.axis('off')

plt.scatter(X_test[:,0], X_test[:,1], c=prediction_values[:,0], cmap=cm.coolwarm)
plt.title('Decision Boundary and model predictions on Test set ')
# Out:
# Text(0.5,1,'Decision Boundary and model predictions on Test set ')

# %% [markdown]
# ## Sidenote: Keraspandas
#
# The "funny" meme tells us:
#
# <img src="http://www.sintetia.com/wp-content/uploads/2014/05/Data-Scientist-What-I-really-do.png" width=600 heigth=600>
#
# The biggest effort is always the preparation of the data, and even for advanced users it is a non-trivial effort to get the data into a shape that is suitable for a deep NN training.
#
# **Enter `keraspandas`!**
#
# The Keras-pandas library aims to automate the preparation and shaping of Pandas `DataFrame`-s into a "feeder" with minimal effort, that is capable of supporting a Keras (and in fact Scikit) based training.
#
# It is an exceptionally good approach for rapid prototyping!
#
# The main class of keraspandas is [`Automater`](https://keras-pandas.readthedocs.io/en/latest/automater.html), which is behaving in an eerily similar way to Scikit's transformers. It needs lists of Pandas `DataFrame.column` names into the appropriate arguments of
# - `numerical_vars`
# - `categorical_vars`
# - `boolean_vars`
# - `datetime_vars`
# - `text_vars`
# - `non_transformed_vars`
#
# so that it can create the appropriate representation for these for the Keras model.
#
# We will see an example below.

# %%
# !pip install -U keras-pandas
# Out:
# Requirement already up-to-date: keras-pandas in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (3.1.0)
# Requirement already satisfied, skipping upgrade: scikit-learn==0.20.0 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from keras-pandas) (0.20.0)
# Requirement already satisfied, skipping upgrade: m2r==0.2.1 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from keras-pandas) (0.2.1)
# Requirement already satisfied, skipping upgrade: Keras==2.2.4 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from keras-pandas) (2.2.4)
# Requirement already satisfied, skipping upgrade: sklearn-pandas==1.7.0 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from keras-pandas) (1.7.0)
# Requirement already satisfied, skipping upgrade: pandas==0.23.4 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from keras-pandas) (0.23.4)
# Requirement already satisfied, skipping upgrade: numpy==1.15.2 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from keras-pandas) (1.15.2)
# Requirement already satisfied, skipping upgrade: xlrd==1.1.0 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from keras-pandas) (1.1.0)
# Requirement already satisfied, skipping upgrade: gensim==3.6.0 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from keras-pandas) (3.6.0)
# Requirement already satisfied, skipping upgrade: tensorflow==1.11.0 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from keras-pandas) (1.11.0)
# Requirement already satisfied, skipping upgrade: h5py==2.8.0 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from keras-pandas) (2.8.0)
# Requirement already satisfied, skipping upgrade: requests==2.20.1 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from keras-pandas) (2.20.1)
# Requirement already satisfied, skipping upgrade: scipy>=0.13.3 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from scikit-learn==0.20.0->keras-pandas) (1.1.0)
# Requirement already satisfied, skipping upgrade: mistune in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from m2r==0.2.1->keras-pandas) (0.8.3)
# Requirement already satisfied, skipping upgrade: docutils in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from m2r==0.2.1->keras-pandas) (0.15.2)
# Requirement already satisfied, skipping upgrade: pyyaml in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from Keras==2.2.4->keras-pandas) (3.13)
# Requirement already satisfied, skipping upgrade: keras-applications>=1.0.6 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from Keras==2.2.4->keras-pandas) (1.0.8)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from Keras==2.2.4->keras-pandas) (1.11.0)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.0.5 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from Keras==2.2.4->keras-pandas) (1.1.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.5.0 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from pandas==0.23.4->keras-pandas) (2.7.3)
# Requirement already satisfied, skipping upgrade: pytz>=2011k in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from pandas==0.23.4->keras-pandas) (2018.5)
# Requirement already satisfied, skipping upgrade: smart-open>=1.2.1 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from gensim==3.6.0->keras-pandas) (1.8.4)
# Requirement already satisfied, skipping upgrade: absl-py>=0.1.6 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from tensorflow==1.11.0->keras-pandas) (0.3.0)
# Requirement already satisfied, skipping upgrade: gast>=0.2.0 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from tensorflow==1.11.0->keras-pandas) (0.2.0)
# Requirement already satisfied, skipping upgrade: astor>=0.6.0 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from tensorflow==1.11.0->keras-pandas) (0.7.1)
# Requirement already satisfied, skipping upgrade: setuptools<=39.1.0 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from tensorflow==1.11.0->keras-pandas) (39.1.0)
# Requirement already satisfied, skipping upgrade: protobuf>=3.6.0 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from tensorflow==1.11.0->keras-pandas) (3.10.0)
# Requirement already satisfied, skipping upgrade: tensorboard<1.12.0,>=1.11.0 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from tensorflow==1.11.0->keras-pandas) (1.11.0)
# Requirement already satisfied, skipping upgrade: wheel>=0.26 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from tensorflow==1.11.0->keras-pandas) (0.33.4)
# Requirement already satisfied, skipping upgrade: termcolor>=1.1.0 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from tensorflow==1.11.0->keras-pandas) (1.1.0)
# Requirement already satisfied, skipping upgrade: grpcio>=1.8.6 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from tensorflow==1.11.0->keras-pandas) (1.12.1)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from requests==2.20.1->keras-pandas) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from requests==2.20.1->keras-pandas) (2018.4.16)
# Requirement already satisfied, skipping upgrade: urllib3<1.25,>=1.21.1 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from requests==2.20.1->keras-pandas) (1.23)
# Requirement already satisfied, skipping upgrade: idna<2.8,>=2.5 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from requests==2.20.1->keras-pandas) (2.7)
# Requirement already satisfied, skipping upgrade: boto3 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from smart-open>=1.2.1->gensim==3.6.0->keras-pandas) (1.9.248)
# Requirement already satisfied, skipping upgrade: boto>=2.32 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from smart-open>=1.2.1->gensim==3.6.0->keras-pandas) (2.49.0)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.10 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from tensorboard<1.12.0,>=1.11.0->tensorflow==1.11.0->keras-pandas) (0.14.1)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from tensorboard<1.12.0,>=1.11.0->tensorflow==1.11.0->keras-pandas) (2.6.11)
# Requirement already satisfied, skipping upgrade: jmespath<1.0.0,>=0.7.1 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from boto3->smart-open>=1.2.1->gensim==3.6.0->keras-pandas) (0.9.4)
# Requirement already satisfied, skipping upgrade: s3transfer<0.3.0,>=0.2.0 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from boto3->smart-open>=1.2.1->gensim==3.6.0->keras-pandas) (0.2.1)
# Requirement already satisfied, skipping upgrade: botocore<1.13.0,>=1.12.248 in /Users/miklostoth/anaconda3/envs/10ai/lib/python3.6/site-packages (from boto3->smart-open>=1.2.1->gensim==3.6.0->keras-pandas) (1.12.248)

# %% [markdown]
# ## Functional API + Keraspandas example

# %%
# Bad practice, but good if you present a notebook :-)
import warnings
warnings.filterwarnings('ignore')


#original from keraspandas example

import matplotlib.pyplot as plt

from keras import Model
from keras.layers import Dense

from keras_pandas.Automater import Automater
from keras_pandas.lib import load_titanic

observations = load_titanic()
#observations.pclass = observations.pclass.astype("str")
print("Type of laded data:", type(observations))

# Transform the data set, using keras_pandas
categorical_vars = ['pclass', 'sex', 'survived']

for cat in categorical_vars:
    observations[cat]=observations[cat].astype("str")


numerical_vars = ['age', 'siblings_spouses_aboard', 'parents_children_aboard', 'fare']
text_vars = ['name']

data_type_dict = {'categorical':categorical_vars, 'numerical':numerical_vars, 'text':text_vars}

# This is the main keraspandas object, accepting the lists of the variables to be transformed 
auto = Automater(data_type_dict=data_type_dict, output_var='survived')

# As with a Scikit based transformer, the data gets transformed
X, y = auto.fit_transform(observations)
# Please mind the _capital X_

# Start model with provided input nub - the product of the keraspandas transformation
x = auto.input_nub

# Fill in your own hidden layers, build up the chain of calls
# Please mind, that in this case we do not even bother with input_shape for the first layer
# as in case of the Sequential API https://keras.io/getting-started/sequential-model-guide/#specifying-the-input-shape
x = Dense(32)(x)
x = Dense(32, activation='relu')(x)
x = Dense(32)(x)
# The set of layers is quite broad and contains convnets, LSTMs, dropout,...
# https://keras.io/layers/about-keras-layers/

# End model with provided output nub - again courtesy of keraspanda - think "onehot encoding"
x = auto.output_nub(x)

# We instantiate and compile the model
model = Model(inputs=auto.input_layers, outputs=x)
# For total lazyness we use keraspandas autoloss, but can switch to others naturally
model.compile(optimizer='Adam', loss=auto.suggest_loss(), metrics=['accuracy'])
# It is important to note, that "Callbacks" can be added here, which can serve as loggers, model savers,...
# Tensorboard has it's own callback
# Custom callbacks can be developed also, that are executed after batch, before batch, after epoch, before,...
# See: https://keras.io/callbacks/

epochs=4

# Train model - really scikit style!
hist = model.fit(X, y, epochs=epochs, validation_split=.2)

print(hist.history)
plt.plot(range(epochs),hist.history["val_acc"])
plt.plot(range(epochs),hist.history["acc"])
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.show()
# Out:
# Type of laded data: <class 'pandas.core.frame.DataFrame'>
# Train on 709 samples, validate on 178 samples
# Epoch 1/4
# 709/709 [==============================] - 4s 5ms/step - loss: 0.9473 - acc: 0.5966 - val_loss: 0.5876 - val_acc: 0.7360
# Epoch 2/4
# 709/709 [==============================] - 0s 542us/step - loss: 0.5011 - acc: 0.8082 - val_loss: 0.4317 - val_acc: 0.8539
# Epoch 3/4
# 709/709 [==============================] - 0s 549us/step - loss: 0.2440 - acc: 0.8858 - val_loss: 0.5564 - val_acc: 0.8090
# Epoch 4/4
# 709/709 [==============================] - 0s 548us/step - loss: 0.0710 - acc: 0.9845 - val_loss: 0.6922 - val_acc: 0.7921
# {'val_loss': [0.5875951875461621, 0.43172419339083556, 0.5563647090718987, 0.6922262545382039], 'val_acc': [0.7359550581889206, 0.8539325856090931, 0.8089887627055136, 0.7921348328001043], 'loss': [0.9473334500416378, 0.5010508902066181, 0.24397258378554804, 0.07099282953261604], 'acc': [0.596614950802834, 0.8081805360502181, 0.8857545839210155, 0.9844851904090268]}

# %% [markdown]
# And we managed to overfit. :-D
#
#
# # End note: Keras and Scikit
#
# Naturally enough, Keras' `.fit() - .predict()` syntax is not accidental.
#
# It is not just true, that Keras got inspiration from Scikit-Learn, but that it is actively developed to be compatible for example with the `pipeline` of Scikit, or can be part of a "grid search" for parameters with `sklearn.model_selection.GridSearchCV`
#
# See more [here](https://keras.io/scikit-learn-api/)
#
# ## Example code
#
# [Source](https://machinelearningmastery.com/use-keras-deep-learning-models-scikit-learn-python/)
#
# (This is indeed not a realistic scenario, the parameters over which we do the grid are not well thought out. Purpose is: show how it works.)

# %%
# Bad practice, but good if you present a notebook :-)
import warnings
warnings.filterwarnings('ignore')


# MLP for Pima Indians Dataset with grid search via sklearn
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
import numpy
 
# Function to create model, required for KerasClassifier
def create_model(optimizer='rmsprop', init='glorot_uniform'):
    # create model
    model = Sequential()
    model.add(Dense(12, input_dim=8, kernel_initializer=init, activation='relu'))
    model.add(Dense(8, kernel_initializer=init, activation='relu'))
    model.add(Dense(1, kernel_initializer=init, activation='sigmoid'))
    # Compile model
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model
 
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# load pima indians dataset

# !wget https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv

dataset = numpy.loadtxt("pima-indians-diabetes.data.csv", delimiter=",")
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]
# create model
model = KerasClassifier(build_fn=create_model, verbose=0)
# grid search epochs, batch size and optimizer
optimizers = ['rmsprop', 'adam']
init = ['glorot_uniform']#, 'normal', 'uniform']
epochs = [2, 5, 10]
batches = [5, 10]
param_grid = dict(optimizer=optimizers, epochs=epochs, batch_size=batches, init=init)
grid = GridSearchCV(estimator=model, param_grid=param_grid, cv=2, verbose=3)
grid_result = grid.fit(X, Y)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# --2019-10-13 09:48:47--  https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.112.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.112.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23278 (23K) [text/plain]
# Saving to: ‘pima-indians-diabetes.data.csv’
#
# pima-indians-diabet 100%[===================>]  22.73K  --.-KB/s    in 0.03s
#
# 2019-10-13 09:48:48 (794 KB/s) - ‘pima-indians-diabetes.data.csv’ saved [23278/23278]
#
# Fitting 2 folds for each of 12 candidates, totalling 24 fits
# [CV] batch_size=5, epochs=2, init=glorot_uniform, optimizer=rmsprop ..
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  batch_size=5, epochs=2, init=glorot_uniform, optimizer=rmsprop, score=0.5781250121848037, total=   1.1s
# [CV] batch_size=5, epochs=2, init=glorot_uniform, optimizer=rmsprop ..
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# [CV]  batch_size=5, epochs=2, init=glorot_uniform, optimizer=rmsprop, score=0.6458333459061881, total=   1.0s
# [CV] batch_size=5, epochs=2, init=glorot_uniform, optimizer=adam .....
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.2s remaining:    0.0s
# [CV]  batch_size=5, epochs=2, init=glorot_uniform, optimizer=adam, score=0.5729166793559367, total=   1.2s
# [CV] batch_size=5, epochs=2, init=glorot_uniform, optimizer=adam .....
# [CV]  batch_size=5, epochs=2, init=glorot_uniform, optimizer=adam, score=0.5104166776485121, total=   1.3s
# [CV] batch_size=5, epochs=5, init=glorot_uniform, optimizer=rmsprop ..
# [CV]  batch_size=5, epochs=5, init=glorot_uniform, optimizer=rmsprop, score=0.6145833464106545, total=   1.2s
# [CV] batch_size=5, epochs=5, init=glorot_uniform, optimizer=rmsprop ..
# [CV]  batch_size=5, epochs=5, init=glorot_uniform, optimizer=rmsprop, score=0.6093750133101518, total=   1.2s
# [CV] batch_size=5, epochs=5, init=glorot_uniform, optimizer=adam .....
# [CV]  batch_size=5, epochs=5, init=glorot_uniform, optimizer=adam, score=0.6197916782693937, total=   1.4s
# [CV] batch_size=5, epochs=5, init=glorot_uniform, optimizer=adam .....
# [CV]  batch_size=5, epochs=5, init=glorot_uniform, optimizer=adam, score=0.5859375139310335, total=   1.6s
# [CV] batch_size=5, epochs=10, init=glorot_uniform, optimizer=rmsprop .
# [CV]  batch_size=5, epochs=10, init=glorot_uniform, optimizer=rmsprop, score=0.6432291802096491, total=   1.7s
# [CV] batch_size=5, epochs=10, init=glorot_uniform, optimizer=rmsprop .
# [CV]  batch_size=5, epochs=10, init=glorot_uniform, optimizer=rmsprop, score=0.6276041805588951, total=   1.7s
# [CV] batch_size=5, epochs=10, init=glorot_uniform, optimizer=adam ....
# [CV]  batch_size=5, epochs=10, init=glorot_uniform, optimizer=adam, score=0.6744791783081988, total=   1.9s
# [CV] batch_size=5, epochs=10, init=glorot_uniform, optimizer=adam ....
# [CV]  batch_size=5, epochs=10, init=glorot_uniform, optimizer=adam, score=0.7057291772604609, total=   2.1s
# [CV] batch_size=10, epochs=2, init=glorot_uniform, optimizer=rmsprop .
# [CV]  batch_size=10, epochs=2, init=glorot_uniform, optimizer=rmsprop, score=0.6015625094684461, total=   1.3s
# [CV] batch_size=10, epochs=2, init=glorot_uniform, optimizer=rmsprop .
# [CV]  batch_size=10, epochs=2, init=glorot_uniform, optimizer=rmsprop, score=0.6588541728754839, total=   1.4s
# [CV] batch_size=10, epochs=2, init=glorot_uniform, optimizer=adam ....
# [CV]  batch_size=10, epochs=2, init=glorot_uniform, optimizer=adam, score=0.6067708416376263, total=   1.6s
# [CV] batch_size=10, epochs=2, init=glorot_uniform, optimizer=adam ....
# [CV]  batch_size=10, epochs=2, init=glorot_uniform, optimizer=adam, score=0.609375002173086, total=   1.6s
# [CV] batch_size=10, epochs=5, init=glorot_uniform, optimizer=rmsprop .
# [CV]  batch_size=10, epochs=5, init=glorot_uniform, optimizer=rmsprop, score=0.6015625072953602, total=   1.5s
# [CV] batch_size=10, epochs=5, init=glorot_uniform, optimizer=rmsprop .
# [CV]  batch_size=10, epochs=5, init=glorot_uniform, optimizer=rmsprop, score=0.6744791750485698, total=   1.7s
# [CV] batch_size=10, epochs=5, init=glorot_uniform, optimizer=adam ....
# [CV]  batch_size=10, epochs=5, init=glorot_uniform, optimizer=adam, score=0.5338541704695672, total=   1.7s
# [CV] batch_size=10, epochs=5, init=glorot_uniform, optimizer=adam ....
# [CV]  batch_size=10, epochs=5, init=glorot_uniform, optimizer=adam, score=0.5130208381063616, total=   1.8s
# [CV] batch_size=10, epochs=10, init=glorot_uniform, optimizer=rmsprop
# [CV]  batch_size=10, epochs=10, init=glorot_uniform, optimizer=rmsprop, score=0.6223958372138441, total=   1.8s
# [CV] batch_size=10, epochs=10, init=glorot_uniform, optimizer=rmsprop
# [CV]  batch_size=10, epochs=10, init=glorot_uniform, optimizer=rmsprop, score=0.6796875018626451, total=   1.9s
# [CV] batch_size=10, epochs=10, init=glorot_uniform, optimizer=adam ...
# [CV]  batch_size=10, epochs=10, init=glorot_uniform, optimizer=adam, score=0.5937500071401397, total=   2.1s
# [CV] batch_size=10, epochs=10, init=glorot_uniform, optimizer=adam ...
# [CV]  batch_size=10, epochs=10, init=glorot_uniform, optimizer=adam, score=0.6562500023283064, total=   2.1s
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:   38.4s finished
# Best: 0.690104 using {'batch_size': 5, 'epochs': 10, 'init': 'glorot_uniform', 'optimizer': 'adam'}
# 0.611979 (0.033854) with: {'batch_size': 5, 'epochs': 2, 'init': 'glorot_uniform', 'optimizer': 'rmsprop'}
# 0.541667 (0.031250) with: {'batch_size': 5, 'epochs': 2, 'init': 'glorot_uniform', 'optimizer': 'adam'}
# 0.611979 (0.002604) with: {'batch_size': 5, 'epochs': 5, 'init': 'glorot_uniform', 'optimizer': 'rmsprop'}
# 0.602865 (0.016927) with: {'batch_size': 5, 'epochs': 5, 'init': 'glorot_uniform', 'optimizer': 'adam'}
# 0.635417 (0.007812) with: {'batch_size': 5, 'epochs': 10, 'init': 'glorot_uniform', 'optimizer': 'rmsprop'}
# 0.690104 (0.015625) with: {'batch_size': 5, 'epochs': 10, 'init': 'glorot_uniform', 'optimizer': 'adam'}
# 0.630208 (0.028646) with: {'batch_size': 10, 'epochs': 2, 'init': 'glorot_uniform', 'optimizer': 'rmsprop'}
# 0.608073 (0.001302) with: {'batch_size': 10, 'epochs': 2, 'init': 'glorot_uniform', 'optimizer': 'adam'}
# 0.638021 (0.036458) with: {'batch_size': 10, 'epochs': 5, 'init': 'glorot_uniform', 'optimizer': 'rmsprop'}
# 0.523438 (0.010417) with: {'batch_size': 10, 'epochs': 5, 'init': 'glorot_uniform', 'optimizer': 'adam'}
# 0.651042 (0.028646) with: {'batch_size': 10, 'epochs': 10, 'init': 'glorot_uniform', 'optimizer': 'rmsprop'}
# 0.625000 (0.031250) with: {'batch_size': 10, 'epochs': 10, 'init': 'glorot_uniform', 'optimizer': 'adam'}

# %% [markdown]
# ## Finally: Full circle
#
# And even more importantly, since Keras has Tensorflow as backend, and it is itself (more and more dominant) part of TF, we came full circle, and get back to being able to use TF under Scikit, proving the interconnectedness of the Python AI stack, for example the powerful [Scikit-Optimize](https://scikit-optimize.github.io/notebooks/sklearn-gridsearchcv-replacement.html) hyperparameter optimization library, which is a drop-in replacement for Scikit's GridSearchCV. Besides this [Dask](https://github.com/dask/dask) as a new player in parallelization of Pythonic workloads (with a Pandas syntax and a strong task scheduler), and because of Dask compatibility the nascent [Rapids](https://developer.nvidia.com/rapids) environment is also converging to be unified, thus promiosing huge boost with parallelisms and GPU workflows (as an alternative to the strong, but really complex parallel solutions of TF itself).
#
# (Sidenote: Though immature and quite dangerous in a sense - like usage without understanding - the machine learning workflow gets more and more automated, so whoever enjoyed Keraspandas, will most probably like [auto_ml](https://auto-ml.readthedocs.io/en/latest/index.html) as well.)
